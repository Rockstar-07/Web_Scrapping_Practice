# %%
import requests
from bs4 import BeautifulSoup
url="https://www.amazon.in/gp/bestsellers/sports/ref=zg_bs_pg_1?ie=UTF8&pg=1"
page=requests.get(url)
soup=BeautifulSoup(page.content,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <link href="https://images-eu.ssl-images-amazon.com/images/I/21GOoQKemTL._RC|01WTbMujHuL.css_.css?AUIClients/ZeitgeistPageAssets-zeitgeistList" rel="stylesheet"/>
# ...

# %%
list = soup.find_all(class_="zg-item-immersion")
len(list)
# Out:
# 50

# %%
first=list[0]
first
# Out:
# <li class="zg-item-immersion" role="gridcell"><span class="a-list-item"><div class="a-section a-spacing-none aok-relative"><div class="a-row a-spacing-none aok-inline-block"><span class="a-size-small aok-float-left zg-badge-body zg-badge-color"><span class="zg-badge-text">#1</span></span><span class="aok-float-left zg-badge-triangle zg-badge-color"></span></div><span class="aok-inline-block zg-item"><a class="a-link-normal" href="/Smart-AMOLED-Display-Battery-Resistant/dp/B08GXC2NTX?_encoding=UTF8&amp;psc=1"><span class="zg-text-center-align"><div class="a-section a-spacing-small"><img alt="Mi Smart Band 5-1.1” AMOLED Color Display, 2 Weeks Battery Life, 5ATM Water Resistant" height="200" src="https://images-eu.ssl-images-amazon.com/images/I/719ZywAmvOL._AC_UL200_SR200,200_.jpg" width="200"/></div></span>
# <div aria-hidden="true" class="p13n-sc-truncate p13n-sc-line-clamp-2 p13n-sc-truncate-desktop-type2" data-rows="2">
# ...

# %%
name=first.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip()
name
# Out:
# 'Mi Smart Band 5-1.1” AMOLED Color Display, 2 Weeks Battery Life, 5ATM Water Resistant'

# %%
price=first.find(class_="p13n-sc-price").get_text().replace('₹\xa0','')
price
# Out:
# '2,499.00'

# %%
second=list[1]
name2=second.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip()
price2=second.find(class_="p13n-sc-price").get_text().replace('₹\xa0','')
rate=second.find(class_="a-icon-alt").get_text()
rate
# Out:
# '4.2 out of 5 stars'

# %%
names,prices,ratings=[],[],[]
for d in list:
    if d.find(class_="a=icon-alt")!=None:
        names.append(d.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip())
        prices.append(d.find(class_="p13n-sc-price").get_text().replace('₹\xa0',''))
        ratings.append(d.find(class_="a-icon-alt").get_text())
    else:
        names.append(d.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip())
        prices.append(d.find(class_="p13n-sc-price").get_text().replace('₹\xa0',''))
        ratings.append(None)

# %%
len(names),len(prices),len(ratings)
# Out:
# (50, 50, 50)

# %%
names,prices,ratings=[],[],[]
for i in range(1,3):
    url2=f"https://www.amazon.in/gp/bestsellers/sports/ref=zg_bs_pg_{i}?ie=UTF8&pg={i}"
    page=requests.get(url2)
    soup=BeautifulSoup(page.content,'html.parser')
    books=soup.find_all(class_="zg-item-immersion")
    for d in list:
        if d.find(class_="a-icon-alt")!=None:
            names.append(d.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip())
            prices.append(d.find(class_="p13n-sc-price").get_text().replace('₹\xa0',''))
            ratings.append(d.find(class_="a-icon-alt").get_text())
        else:
            names.append(d.find(class_="p13n-sc-truncate-desktop-type2").get_text().strip())
            prices.append(d.find(class_="p13n-sc-price").get_text().replace('₹\xa0',''))
            ratings.append(None)

# %%
len(names),len(prices),len(ratings)
# Out:
# (100, 100, 100)

# %%
import pandas as pd
d={'Names':names,'Prices':prices,'Ratings':ratings}
df=pd.DataFrame(d)
df.head(20)
# Out:
#                                                 Names    Prices  \
# 0   Mi Smart Band 5-1.1” AMOLED Color Display, 2 W...  2,499.00
# 1                  Fitkit Classic Bottle Shaker 700ml    126.00
# 2   Mi Smart Band 4- India's No.1 Fitness Band, Up...  1,949.00
# 3   Fitness Mantra® Yoga Mat for Gym Workout and Y...    369.00
# 4   Yonex Mavis 350 Nylon Shuttlecock (Pack of 6) ...    999.00
# 5   Yonex Mavis 200i Nylon Shuttle Cock, Pack of 6...    475.00
# 6   Yonex ZR 100 Light Aluminium Badminton Racquet...    529.00
# 7   OnePlus Band :1.1” AMOLED Display, Dual-Color ...  2,499.00
# 8                       Nivia Storm Football - Size 5    359.00
# 9   Aurion Skipping-Rope Jump Skipping Rope for Me...    129.00
# 10  Kore PVC 16-30 Kg Home Gym Set with One 3 Ft C...  1,429.00
# 11             Nivia 11041 Cotton Thumb Wrist Support    199.00
# 12  HONOR Band 5 (CoralPink)- Waterproof Full Colo...  2,199.00
# 13  Aurion Set of 2 PVC Dumbbells Weights Fitness ...    198.00
# ...

# %%
df.to_csv('Best_Seller_in_Sports.csv',index=False)
